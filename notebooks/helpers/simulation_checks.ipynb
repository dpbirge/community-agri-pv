# %%
# Imports
import sys; sys.path.insert(0, '..')
from src.community_demand import load_demands
from src.energy_supply import load_energy
from src.plots import plot_demands, plot_energy_generation

# %%
# Stacked area plots of energy and water demand by building type
plot_demands(load_demands('../simulation/community_daily_demands.csv'), years=1)
# Out:
# (<Figure size 1400x500 with 1 Axes>, <Figure size 1400x500 with 1 Axes>)

# %%
# Stacked area plot of daily energy generation by source
plot_energy_generation(load_energy('../simulation/daily_energy_generation.csv'), years=1)
